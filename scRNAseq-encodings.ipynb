# %%
#load relevant packages

import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad
import matplotlib.pyplot as plt
import joblib
import scvae

# %%
fused_set = scvae.
parental_set = scvae.data.DataSet("./parental/matrix.mtx.gz")
resistant_set = scvae.data.DataSet("./resistant/matrix.mtx.gz")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 fused_set = scvae.data.DataSet("./fused/matrix.mtx.gz")
#       2 parental_set = scvae.data.DataSet("./parental/matrix.mtx.gz")
#       3 resistant_set = scvae.data.DataSet("./resistant/matrix.mtx.gz")
#
# AttributeError: module 'scvae' has no attribute 'data'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 scvae.train
#
# AttributeError: module 'scvae' has no attribute 'train'
